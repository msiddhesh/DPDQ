# %%
# !pip install -q pyspark==3.2.0
from pyspark.sql import SparkSession, Row
# !pyspark --version
# %env SPARK_VERSION=3.3
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.11/dist-packages/pyspark/jars/spark-unsafe_2.12-3.2.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 3.2.0
#       /_/
#
# Using Scala version 2.12.15, OpenJDK 64-Bit Server VM, 11.0.26
# Branch HEAD
# Compiled by user ubuntu on 2021-10-06T12:46:30Z
# Revision 5d45a415f3a29898d92380380cfd82bfc7f579ea
# Url https://github.com/apache/spark
# Type --help for more information.
# env: SPARK_VERSION=3.3

# %%
# !pip install pydeequ
# Out:
# Requirement already satisfied: pydeequ in /usr/local/lib/python3.11/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.11/dist-packages (from pydeequ) (2.0.2)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from pydeequ) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23.0->pydeequ) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23.0->pydeequ) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23.0->pydeequ) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23.0->pydeequ) (1.17.0)

# %%
import pydeequ
from pydeequ.profiles import *
import os
import kagglehub
import pandas as pd
spark = (SparkSession
    .builder
    .config("spark.jars.packages", pydeequ.deequ_maven_coord)
    .config("spark.jars.excludes", pydeequ.f2j_maven_coord)
    .getOrCreate())

# %%
import pandas as pd

# %%
# Download latest version from Kaggle
dataset_path = kagglehub.dataset_download("siddheshmaheshwari/adult")
print("Path to dataset files:", dataset_path)

# Load data (adjust file names based on what's available in the dataset)
train_file = os.path.join(dataset_path, "adult.data")
test_file = os.path.join(dataset_path, "adult.test")
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/siddheshmaheshwari/adult?dataset_version_number=2...
# 100%|██████████| 708k/708k [00:00<00:00, 1.14MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/siddheshmaheshwari/adult/versions/2

# %%
column_names = [
    'age', 'workclass', "fnlwgt",'education', 'education-num', 'marital-status',
    'occupation', 'relationship', 'race', 'sex', 'capital-gain',
    'capital-loss', 'hours-per-week', 'native-country', 'income'
]

adult_data = pd.read_csv(train_file, names=column_names)
adult_test = pd.read_csv(test_file, names=column_names)
adult_test.drop(index=0,inplace=True)

adult_data_full = pd.concat([adult_data, adult_test], axis=0)

adult_data_full.index = adult_data_full.index.astype(str)

int_columns = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
for col in int_columns:
    adult_data_full[col] = adult_data_full[col].astype(int)

# %%
# Save the DataFrame to a CSV file in Google Drive
from google.colab import drive
drive.mount('/content/drive')

csv_file_path = '/content/drive/MyDrive/adult_data_full.csv'  # Specify the desired path
adult_data_full.to_csv(csv_file_path, index=False) # Set index=False to avoid saving the index

print(f"Data saved to: {csv_file_path}")
# Out:
# Mounted at /content/drive
# Data saved to: /content/drive/MyDrive/adult_data_full.csv

# %%
# Cell 2: Import libraries
import json
from pyspark.sql import SparkSession
import pydeequ
from pydeequ.profiles import ColumnProfilerRunner
from pydeequ.suggestions import ConstraintSuggestionRunner, DEFAULT
from pydeequ.checks import Check, CheckLevel
from pydeequ.verification import VerificationSuite, VerificationResult
from pydeequ.suggestions import *
from pydeequ.analyzers import (
    AnalysisRunner,
    AnalyzerContext,
    Size,
    Completeness,
    Mean,
    ApproxCountDistinct,
    CountDistinct
)

# %%
# Cell 3: Create Spark session
spark = (SparkSession
    .builder
    .appName("PyDeequ Analysis")
    .config("spark.jars.packages", pydeequ.deequ_maven_coord)
    .config("spark.jars.excludes", pydeequ.f2j_maven_coord)
    .getOrCreate())

# %%
# Cell 4: Load dataset
# Replace the path with the actual location of your adult_data file
adult_data = spark.read.option("header", "true").csv("/content/drive/MyDrive/adult_data_full.csv")
adult_data.show(5)
# Out:
# +---+-----------------+------+----------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+
# |age|        workclass|fnlwgt| education|education-num|     marital-status|        occupation|  relationship|  race|    sex|capital-gain|capital-loss|hours-per-week|native-country|income|
# +---+-----------------+------+----------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+
# | 39|        State-gov| 77516| Bachelors|           13|      Never-married|      Adm-clerical| Not-in-family| White|   Male|        2174|           0|            40| United-States| <=50K|
# | 50| Self-emp-not-inc| 83311| Bachelors|           13| Married-civ-spouse|   Exec-managerial|       Husband| White|   Male|           0|           0|            13| United-States| <=50K|
# | 38|          Private|215646|   HS-grad|            9|           Divorced| Handlers-cleaners| Not-in-family| White|   Male|           0|           0|            40| United-States| <=50K|
# | 53|          Private|234721|      11th|            7| Married-civ-spouse| Handlers-cleaners|       Husband| Black|   Male|           0|           0|            40| United-States| <=50K|
# | 28|          Private|338409| Bachelors|           13| Married-civ-spouse|    Prof-specialty|          Wife| Black| Female|           0|           0|            40|          Cuba| <=50K|
# +---+-----------------+------+----------+-------------+-------------------+------------------+--------------+------+-------+------------+------------+--------------+--------------+------+
# only showing top 5 rows

# %%
# Cell 5: Column Profiling
print("=== Running Column Profiling ===")
profile_result = ColumnProfilerRunner(spark).onData(adult_data).run()

# Print profiling results
for col, profile in profile_result.profiles.items():
    print(f"Column: {col}")
    print(f"  Completeness: {profile.completeness}")
    print(f"  Distinct values: {profile.approximateNumDistinctValues}")
    print(f"  Data type: {profile.dataType}")
    print()
# Out:
# === Running Column Profiling ===
# Column: hours-per-week
#   Completeness: 1.0
#   Distinct values: 99
#   Data type: Integral
#
# Column: capital-gain
#   Completeness: 1.0
#   Distinct values: 130
#   Data type: Integral
#
# Column: education-num
#   Completeness: 1.0
#   Distinct values: 16
#   Data type: Integral
#
# Column: marital-status
#   Completeness: 1.0
#   Distinct values: 7
#   Data type: String
#
# Column: age
#   Completeness: 1.0
#   Distinct values: 76
#   Data type: Integral
#
# Column: sex
#   Completeness: 1.0
#   Distinct values: 2
#   Data type: String
#
# Column: relationship
#   Completeness: 1.0
#   Distinct values: 6
#   Data type: String
#
# Column: education
#   Completeness: 1.0
#   Distinct values: 16
#   Data type: String
#
# Column: income
#   Completeness: 1.0
#   Distinct values: 4
#   Data type: String
#
# Column: race
#   Completeness: 1.0
#   Distinct values: 5
#   Data type: String
#
# Column: native-country
#   Completeness: 1.0
#   Distinct values: 39
#   Data type: String
#
# Column: fnlwgt
#   Completeness: 1.0
#   Distinct values: 27906
#   Data type: Integral
#
# Column: workclass
#   Completeness: 1.0
#   Distinct values: 9
#   Data type: String
#
# Column: capital-loss
#   Completeness: 1.0
#   Distinct values: 100
#   Data type: Integral
#
# Column: occupation
#   Completeness: 1.0
#   Distinct values: 15
#   Data type: String

# %%
# Cell 6: Generate Constraint Suggestions
print("=== Generating Constraint Suggestions ===")
suggestion_result = (ConstraintSuggestionRunner(spark)
    .onData(adult_data)
    .addConstraintRule(DEFAULT())
    .run())

# Print constraint suggestions in JSON format
print(json.dumps(suggestion_result, indent=2))
# Out:
# === Generating Constraint Suggestions ===
# {
#   "constraint_suggestions": [
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('hours-per-week' has value range '40', '50', '45', '60', '35', '20', '30', '55', '25', '48', '38', '15', '70', '10', '32', '65', '24', '42', '36', '44', '16', '12', '37', '43', '8', '80', '52', '56', '28', '99', '18', '46', '72', '75', '5', '6', '4', '47', '84', '39', '54', '22', '33', '3', '41', '14', '2', '34', '21', '7', '27', '17', '90', '26', '23', '53', '49', '58', '13', '1', '9', '62', '66', '64', '11', '51', '57', '19', '85', '68', '63', '29', '98', '78', '31', '96', '77', '59', '67', '86', '76', '61', '88', '73', '91', '74', '92', '81', '89', '97', '95', '69', '82', '87', '79', '94',`hours-per-week` IN ('40', '50', '45', '60', '35', '20', '30', '55', '25', '48', '38', '15', '70', '10', '32', '65', '24', '42', '36', '44', '16', '12', '37', '43', '8', '80', '52', '56', '28', '99', '18', '46', '72', '75', '5', '6', '4', '47', '84', '39', '54', '22', '33', '3', '41', '14', '2', '34', '21', '7', '27', '17', '90', '26', '23', '53', '49', '58', '13', '1', '9', '62', '66', '64', '11', '51', '57', '19', '85', '68', '63', '29', '98', '78', '31', '96', '77', '59', '67', '86', '76', '61', '88', '73', '91', '74', '92', '81', '89', '97', '95', '69', '82', '87', '79', '94'),None,List(hours-per-week),None))",
#       "column_name": "hours-per-week",
#       "current_value": "Compliance: 1",
#       "description": "'hours-per-week' has value range '40', '50', '45', '60', '35', '20', '30', '55', '25', '48', '38', '15', '70', '10', '32', '65', '24', '42', '36', '44', '16', '12', '37', '43', '8', '80', '52', '56', '28', '99', '18', '46', '72', '75', '5', '6', '4', '47', '84', '39', '54', '22', '33', '3', '41', '14', '2', '34', '21', '7', '27', '17', '90', '26', '23', '53', '49', '58', '13', '1', '9', '62', '66', '64', '11', '51', '57', '19', '85', '68', '63', '29', '98', '78', '31', '96', '77', '59', '67', '86', '76', '61', '88', '73', '91', '74', '92', '81', '89', '97', '95', '69', '82', '87', '79', '94'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"hours-per-week\", [\"40\", \"50\", \"45\", \"60\", \"35\", \"20\", \"30\", \"55\", \"25\", \"48\", \"38\", \"15\", \"70\", \"10\", \"32\", \"65\", \"24\", \"42\", \"36\", \"44\", \"16\", \"12\", \"37\", \"43\", \"8\", \"80\", \"52\", \"56\", \"28\", \"99\", \"18\", \"46\", \"72\", \"75\", \"5\", \"6\", \"4\", \"47\", \"84\", \"39\", \"54\", \"22\", \"33\", \"3\", \"41\", \"14\", \"2\", \"34\", \"21\", \"7\", \"27\", \"17\", \"90\", \"26\", \"23\", \"53\", \"49\", \"58\", \"13\", \"1\", \"9\", \"62\", \"66\", \"64\", \"11\", \"51\", \"57\", \"19\", \"85\", \"68\", \"63\", \"29\", \"98\", \"78\", \"31\", \"96\", \"77\", \"59\", \"67\", \"86\", \"76\", \"61\", \"88\", \"73\", \"91\", \"74\", \"92\", \"81\", \"89\", \"97\", \"95\", \"69\", \"82\", \"87\", \"79\", \"94\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(hours-per-week,None,None))",
#       "column_name": "hours-per-week",
#       "current_value": "Completeness: 1.0",
#       "description": "'hours-per-week' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"hours-per-week\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('hours-per-week' has value range '40', '50', '45', '60', '35', '20', '30', '55', '25', '48', '38', '15', '70', '10', '32', '65', '24', '42', '36' for at least 90.0% of values,`hours-per-week` IN ('40', '50', '45', '60', '35', '20', '30', '55', '25', '48', '38', '15', '70', '10', '32', '65', '24', '42', '36'),None,List(hours-per-week),None))",
#       "column_name": "hours-per-week",
#       "current_value": "Compliance: 0.905491175627534",
#       "description": "'hours-per-week' has value range '40', '50', '45', '60', '35', '20', '30', '55', '25', '48', '38', '15', '70', '10', '32', '65', '24', '42', '36' for at least 90.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"hours-per-week\", [\"40\", \"50\", \"45\", \"60\", \"35\", \"20\", \"30\", \"55\", \"25\", \"48\", \"38\", \"15\", \"70\", \"10\", \"32\", \"65\", \"24\", \"42\", \"36\"], lambda x: x >= 0.9, \"It should be above 0.9!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('hours-per-week' has no negative values,hours-per-week >= 0,None,List(hours-per-week),None))",
#       "column_name": "hours-per-week",
#       "current_value": "Minimum: 1.0",
#       "description": "'hours-per-week' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"hours-per-week\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(hours-per-week,None),<function1>,Some(<function1>),None)",
#       "column_name": "hours-per-week",
#       "current_value": "DataType: Integral",
#       "description": "'hours-per-week' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"hours-per-week\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(capital-gain,None,None))",
#       "column_name": "capital-gain",
#       "current_value": "Completeness: 1.0",
#       "description": "'capital-gain' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"capital-gain\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('capital-gain' has no negative values,capital-gain >= 0,None,List(capital-gain),None))",
#       "column_name": "capital-gain",
#       "current_value": "Minimum: 0.0",
#       "description": "'capital-gain' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"capital-gain\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(capital-gain,None),<function1>,Some(<function1>),None)",
#       "column_name": "capital-gain",
#       "current_value": "DataType: Integral",
#       "description": "'capital-gain' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"capital-gain\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('education-num' has value range '9', '10', '13', '14', '11', '7', '12', '6', '4', '15', '5', '8', '16', '3', '2', '1',`education-num` IN ('9', '10', '13', '14', '11', '7', '12', '6', '4', '15', '5', '8', '16', '3', '2', '1'),None,List(education-num),None))",
#       "column_name": "education-num",
#       "current_value": "Compliance: 1",
#       "description": "'education-num' has value range '9', '10', '13', '14', '11', '7', '12', '6', '4', '15', '5', '8', '16', '3', '2', '1'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"education-num\", [\"9\", \"10\", \"13\", \"14\", \"11\", \"7\", \"12\", \"6\", \"4\", \"15\", \"5\", \"8\", \"16\", \"3\", \"2\", \"1\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(education-num,None,None))",
#       "column_name": "education-num",
#       "current_value": "Completeness: 1.0",
#       "description": "'education-num' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"education-num\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('education-num' has value range '9', '10', '13', '14', '11', '7', '12', '6' for at least 90.0% of values,`education-num` IN ('9', '10', '13', '14', '11', '7', '12', '6'),None,List(education-num),None))",
#       "column_name": "education-num",
#       "current_value": "Compliance: 0.9051021661684616",
#       "description": "'education-num' has value range '9', '10', '13', '14', '11', '7', '12', '6' for at least 90.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"education-num\", [\"9\", \"10\", \"13\", \"14\", \"11\", \"7\", \"12\", \"6\"], lambda x: x >= 0.9, \"It should be above 0.9!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('education-num' has no negative values,education-num >= 0,None,List(education-num),None))",
#       "column_name": "education-num",
#       "current_value": "Minimum: 1.0",
#       "description": "'education-num' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"education-num\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(education-num,None),<function1>,Some(<function1>),None)",
#       "column_name": "education-num",
#       "current_value": "DataType: Integral",
#       "description": "'education-num' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"education-num\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('marital-status' has value range ' Married-civ-spouse', ' Never-married', ' Divorced', ' Separated', ' Widowed', ' Married-spouse-absent', ' Married-AF-spouse',`marital-status` IN (' Married-civ-spouse', ' Never-married', ' Divorced', ' Separated', ' Widowed', ' Married-spouse-absent', ' Married-AF-spouse'),None,List(marital-status),None))",
#       "column_name": "marital-status",
#       "current_value": "Compliance: 1",
#       "description": "'marital-status' has value range ' Married-civ-spouse', ' Never-married', ' Divorced', ' Separated', ' Widowed', ' Married-spouse-absent', ' Married-AF-spouse'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"marital-status\", [\" Married-civ-spouse\", \" Never-married\", \" Divorced\", \" Separated\", \" Widowed\", \" Married-spouse-absent\", \" Married-AF-spouse\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(marital-status,None,None))",
#       "column_name": "marital-status",
#       "current_value": "Completeness: 1.0",
#       "description": "'marital-status' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"marital-status\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('marital-status' has value range ' Married-civ-spouse', ' Never-married', ' Divorced' for at least 92.0% of values,`marital-status` IN (' Married-civ-spouse', ' Never-married', ' Divorced'),None,List(marital-status),None))",
#       "column_name": "marital-status",
#       "current_value": "Compliance: 0.9239793620244872",
#       "description": "'marital-status' has value range ' Married-civ-spouse', ' Never-married', ' Divorced' for at least 92.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"marital-status\", [\" Married-civ-spouse\", \" Never-married\", \" Divorced\"], lambda x: x >= 0.92, \"It should be above 0.92!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('age' has value range '36', '35', '33', '23', '31', '34', '28', '37', '30', '38', '32', '41', '27', '29', '39', '24', '25', '40', '22', '42', '26', '20', '43', '46', '21', '45', '47', '44', '19', '51', '50', '18', '49', '48', '52', '53', '55', '54', '17', '56', '58', '57', '59', '61', '60', '62', '64', '63', '65', '67', '66', '68', '69', '70', '72', '71', '73', '74', '75', '76', '90', '77', '80', '81', '78', '79', '82', '84', '83', '88', '85', '87', '89', '86',`age` IN ('36', '35', '33', '23', '31', '34', '28', '37', '30', '38', '32', '41', '27', '29', '39', '24', '25', '40', '22', '42', '26', '20', '43', '46', '21', '45', '47', '44', '19', '51', '50', '18', '49', '48', '52', '53', '55', '54', '17', '56', '58', '57', '59', '61', '60', '62', '64', '63', '65', '67', '66', '68', '69', '70', '72', '71', '73', '74', '75', '76', '90', '77', '80', '81', '78', '79', '82', '84', '83', '88', '85', '87', '89', '86'),None,List(age),None))",
#       "column_name": "age",
#       "current_value": "Compliance: 1",
#       "description": "'age' has value range '36', '35', '33', '23', '31', '34', '28', '37', '30', '38', '32', '41', '27', '29', '39', '24', '25', '40', '22', '42', '26', '20', '43', '46', '21', '45', '47', '44', '19', '51', '50', '18', '49', '48', '52', '53', '55', '54', '17', '56', '58', '57', '59', '61', '60', '62', '64', '63', '65', '67', '66', '68', '69', '70', '72', '71', '73', '74', '75', '76', '90', '77', '80', '81', '78', '79', '82', '84', '83', '88', '85', '87', '89', '86'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"age\", [\"36\", \"35\", \"33\", \"23\", \"31\", \"34\", \"28\", \"37\", \"30\", \"38\", \"32\", \"41\", \"27\", \"29\", \"39\", \"24\", \"25\", \"40\", \"22\", \"42\", \"26\", \"20\", \"43\", \"46\", \"21\", \"45\", \"47\", \"44\", \"19\", \"51\", \"50\", \"18\", \"49\", \"48\", \"52\", \"53\", \"55\", \"54\", \"17\", \"56\", \"58\", \"57\", \"59\", \"61\", \"60\", \"62\", \"64\", \"63\", \"65\", \"67\", \"66\", \"68\", \"69\", \"70\", \"72\", \"71\", \"73\", \"74\", \"75\", \"76\", \"90\", \"77\", \"80\", \"81\", \"78\", \"79\", \"82\", \"84\", \"83\", \"88\", \"85\", \"87\", \"89\", \"86\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(age,None,None))",
#       "column_name": "age",
#       "current_value": "Completeness: 1.0",
#       "description": "'age' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"age\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('age' has value range '36', '35', '33', '23', '31', '34', '28', '37', '30', '38', '32', '41', '27', '29', '39', '24', '25', '40', '22', '42', '26', '20', '43', '46', '21', '45', '47', '44', '19', '51', '50', '18', '49', '48', '52', '53', '55', '54', '17', '56', '58', '57' for at least 90.0% of values,`age` IN ('36', '35', '33', '23', '31', '34', '28', '37', '30', '38', '32', '41', '27', '29', '39', '24', '25', '40', '22', '42', '26', '20', '43', '46', '21', '45', '47', '44', '19', '51', '50', '18', '49', '48', '52', '53', '55', '54', '17', '56', '58', '57'),None,List(age),None))",
#       "column_name": "age",
#       "current_value": "Compliance: 0.9062691945456777",
#       "description": "'age' has value range '36', '35', '33', '23', '31', '34', '28', '37', '30', '38', '32', '41', '27', '29', '39', '24', '25', '40', '22', '42', '26', '20', '43', '46', '21', '45', '47', '44', '19', '51', '50', '18', '49', '48', '52', '53', '55', '54', '17', '56', '58', '57' for at least 90.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"age\", [\"36\", \"35\", \"33\", \"23\", \"31\", \"34\", \"28\", \"37\", \"30\", \"38\", \"32\", \"41\", \"27\", \"29\", \"39\", \"24\", \"25\", \"40\", \"22\", \"42\", \"26\", \"20\", \"43\", \"46\", \"21\", \"45\", \"47\", \"44\", \"19\", \"51\", \"50\", \"18\", \"49\", \"48\", \"52\", \"53\", \"55\", \"54\", \"17\", \"56\", \"58\", \"57\"], lambda x: x >= 0.9, \"It should be above 0.9!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('age' has no negative values,age >= 0,None,List(age),None))",
#       "column_name": "age",
#       "current_value": "Minimum: 17.0",
#       "description": "'age' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"age\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(age,None),<function1>,Some(<function1>),None)",
#       "column_name": "age",
#       "current_value": "DataType: Integral",
#       "description": "'age' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"age\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('sex' has value range ' Male', ' Female',`sex` IN (' Male', ' Female'),None,List(sex),None))",
#       "column_name": "sex",
#       "current_value": "Compliance: 1",
#       "description": "'sex' has value range ' Male', ' Female'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"sex\", [\" Male\", \" Female\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(sex,None,None))",
#       "column_name": "sex",
#       "current_value": "Completeness: 1.0",
#       "description": "'sex' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"sex\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('relationship' has value range ' Husband', ' Not-in-family', ' Own-child', ' Unmarried', ' Wife', ' Other-relative',`relationship` IN (' Husband', ' Not-in-family', ' Own-child', ' Unmarried', ' Wife', ' Other-relative'),None,List(relationship),None))",
#       "column_name": "relationship",
#       "current_value": "Compliance: 1",
#       "description": "'relationship' has value range ' Husband', ' Not-in-family', ' Own-child', ' Unmarried', ' Wife', ' Other-relative'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"relationship\", [\" Husband\", \" Not-in-family\", \" Own-child\", \" Unmarried\", \" Wife\", \" Other-relative\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(relationship,None,None))",
#       "column_name": "relationship",
#       "current_value": "Completeness: 1.0",
#       "description": "'relationship' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"relationship\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('relationship' has value range ' Husband', ' Not-in-family', ' Own-child', ' Unmarried' for at least 91.0% of values,`relationship` IN (' Husband', ' Not-in-family', ' Own-child', ' Unmarried'),None,List(relationship),None))",
#       "column_name": "relationship",
#       "current_value": "Compliance: 0.9214405634494901",
#       "description": "'relationship' has value range ' Husband', ' Not-in-family', ' Own-child', ' Unmarried' for at least 91.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"relationship\", [\" Husband\", \" Not-in-family\", \" Own-child\", \" Unmarried\"], lambda x: x >= 0.91, \"It should be above 0.91!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('education' has value range ' HS-grad', ' Some-college', ' Bachelors', ' Masters', ' Assoc-voc', ' 11th', ' Assoc-acdm', ' 10th', ' 7th-8th', ' Prof-school', ' 9th', ' 12th', ' Doctorate', ' 5th-6th', ' 1st-4th', ' Preschool',`education` IN (' HS-grad', ' Some-college', ' Bachelors', ' Masters', ' Assoc-voc', ' 11th', ' Assoc-acdm', ' 10th', ' 7th-8th', ' Prof-school', ' 9th', ' 12th', ' Doctorate', ' 5th-6th', ' 1st-4th', ' Preschool'),None,List(education),None))",
#       "column_name": "education",
#       "current_value": "Compliance: 1",
#       "description": "'education' has value range ' HS-grad', ' Some-college', ' Bachelors', ' Masters', ' Assoc-voc', ' 11th', ' Assoc-acdm', ' 10th', ' 7th-8th', ' Prof-school', ' 9th', ' 12th', ' Doctorate', ' 5th-6th', ' 1st-4th', ' Preschool'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"education\", [\" HS-grad\", \" Some-college\", \" Bachelors\", \" Masters\", \" Assoc-voc\", \" 11th\", \" Assoc-acdm\", \" 10th\", \" 7th-8th\", \" Prof-school\", \" 9th\", \" 12th\", \" Doctorate\", \" 5th-6th\", \" 1st-4th\", \" Preschool\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(education,None,None))",
#       "column_name": "education",
#       "current_value": "Completeness: 1.0",
#       "description": "'education' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"education\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('education' has value range ' HS-grad', ' Some-college', ' Bachelors', ' Masters', ' Assoc-voc', ' 11th', ' Assoc-acdm', ' 10th' for at least 90.0% of values,`education` IN (' HS-grad', ' Some-college', ' Bachelors', ' Masters', ' Assoc-voc', ' 11th', ' Assoc-acdm', ' 10th'),None,List(education),None))",
#       "column_name": "education",
#       "current_value": "Compliance: 0.9051021661684616",
#       "description": "'education' has value range ' HS-grad', ' Some-college', ' Bachelors', ' Masters', ' Assoc-voc', ' 11th', ' Assoc-acdm', ' 10th' for at least 90.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"education\", [\" HS-grad\", \" Some-college\", \" Bachelors\", \" Masters\", \" Assoc-voc\", \" 11th\", \" Assoc-acdm\", \" 10th\"], lambda x: x >= 0.9, \"It should be above 0.9!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('income' has value range ' <=50K', ' <=50K.', ' >50K', ' >50K.',`income` IN (' <=50K', ' <=50K.', ' >50K', ' >50K.'),None,List(income),None))",
#       "column_name": "income",
#       "current_value": "Compliance: 1",
#       "description": "'income' has value range ' <=50K', ' <=50K.', ' >50K', ' >50K.'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"income\", [\" <=50K\", \" <=50K.\", \" >50K\", \" >50K.\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(income,None,None))",
#       "column_name": "income",
#       "current_value": "Completeness: 1.0",
#       "description": "'income' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"income\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('income' has value range ' <=50K', ' <=50K.', ' >50K' for at least 91.0% of values,`income` IN (' <=50K', ' <=50K.', ' >50K'),None,List(income),None))",
#       "column_name": "income",
#       "current_value": "Compliance: 0.9212562958109825",
#       "description": "'income' has value range ' <=50K', ' <=50K.', ' >50K' for at least 91.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"income\", [\" <=50K\", \" <=50K.\", \" >50K\"], lambda x: x >= 0.91, \"It should be above 0.91!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('race' has value range ' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other',`race` IN (' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other'),None,List(race),None))",
#       "column_name": "race",
#       "current_value": "Compliance: 1",
#       "description": "'race' has value range ' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"race\", [\" White\", \" Black\", \" Asian-Pac-Islander\", \" Amer-Indian-Eskimo\", \" Other\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(race,None,None))",
#       "column_name": "race",
#       "current_value": "Completeness: 1.0",
#       "description": "'race' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"race\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('race' has value range ' White', ' Black' for at least 94.0% of values,`race` IN (' White', ' Black'),None,List(race),None))",
#       "column_name": "race",
#       "current_value": "Compliance: 0.9509643339748577",
#       "description": "'race' has value range ' White', ' Black' for at least 94.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"race\", [\" White\", \" Black\"], lambda x: x >= 0.94, \"It should be above 0.94!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('native-country' has value range ' United-States', ' Mexico', ' ?', ' Philippines', ' Germany', ' Puerto-Rico', ' Canada', ' El-Salvador', ' India', ' Cuba', ' England', ' China', ' South', ' Jamaica', ' Italy', ' Dominican-Republic', ' Japan', ' Guatemala', ' Poland', ' Vietnam', ' Columbia', ' Haiti', ' Portugal', ' Taiwan', ' Iran', ' Greece', ' Nicaragua', ' Peru', ' Ecuador', ' France', ' Ireland', ' Thailand', ' Hong', ' Cambodia', ' Trinadad&Tobago', ' Outlying-US(Guam-USVI-etc)', ' Yugoslavia', ' Laos', ' Scotland', ' Honduras', ' Hungary', ' Holand-Netherlands',`native-country` IN (' United-States', ' Mexico', ' ?', ' Philippines', ' Germany', ' Puerto-Rico', ' Canada', ' El-Salvador', ' India', ' Cuba', ' England', ' China', ' South', ' Jamaica', ' Italy', ' Dominican-Republic', ' Japan', ' Guatemala', ' Poland', ' Vietnam', ' Columbia', ' Haiti', ' Portugal', ' Taiwan', ' Iran', ' Greece', ' Nicaragua', ' Peru', ' Ecuador', ' France', ' Ireland', ' Thailand', ' Hong', ' Cambodia', ' Trinadad&Tobago', ' Outlying-US(Guam-USVI-etc)', ' Yugoslavia', ' Laos', ' Scotland', ' Honduras', ' Hungary', ' Holand-Netherlands'),None,List(native-country),None))",
#       "column_name": "native-country",
#       "current_value": "Compliance: 1",
#       "description": "'native-country' has value range ' United-States', ' Mexico', ' ?', ' Philippines', ' Germany', ' Puerto-Rico', ' Canada', ' El-Salvador', ' India', ' Cuba', ' England', ' China', ' South', ' Jamaica', ' Italy', ' Dominican-Republic', ' Japan', ' Guatemala', ' Poland', ' Vietnam', ' Columbia', ' Haiti', ' Portugal', ' Taiwan', ' Iran', ' Greece', ' Nicaragua', ' Peru', ' Ecuador', ' France', ' Ireland', ' Thailand', ' Hong', ' Cambodia', ' Trinadad&Tobago', ' Outlying-US(Guam-USVI-etc)', ' Yugoslavia', ' Laos', ' Scotland', ' Honduras', ' Hungary', ' Holand-Netherlands'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"native-country\", [\" United-States\", \" Mexico\", \" ?\", \" Philippines\", \" Germany\", \" Puerto-Rico\", \" Canada\", \" El-Salvador\", \" India\", \" Cuba\", \" England\", \" China\", \" South\", \" Jamaica\", \" Italy\", \" Dominican-Republic\", \" Japan\", \" Guatemala\", \" Poland\", \" Vietnam\", \" Columbia\", \" Haiti\", \" Portugal\", \" Taiwan\", \" Iran\", \" Greece\", \" Nicaragua\", \" Peru\", \" Ecuador\", \" France\", \" Ireland\", \" Thailand\", \" Hong\", \" Cambodia\", \" Trinadad&Tobago\", \" Outlying-US(Guam-USVI-etc]\", \" Yugoslavia\", \" Laos\", \" Scotland\", \" Honduras\", \" Hungary\", \" Holand-Netherlands\"))"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(native-country,None,None))",
#       "column_name": "native-country",
#       "current_value": "Completeness: 1.0",
#       "description": "'native-country' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"native-country\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('native-country' has value range ' United-States', ' Mexico' for at least 91.0% of values,`native-country` IN (' United-States', ' Mexico'),None,List(native-country),None))",
#       "column_name": "native-country",
#       "current_value": "Compliance: 0.9168952950329634",
#       "description": "'native-country' has value range ' United-States', ' Mexico' for at least 91.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"native-country\", [\" United-States\", \" Mexico\"], lambda x: x >= 0.91, \"It should be above 0.91!\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(fnlwgt,None,None))",
#       "column_name": "fnlwgt",
#       "current_value": "Completeness: 1.0",
#       "description": "'fnlwgt' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"fnlwgt\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('fnlwgt' has no negative values,fnlwgt >= 0,None,List(fnlwgt),None))",
#       "column_name": "fnlwgt",
#       "current_value": "Minimum: 12285.0",
#       "description": "'fnlwgt' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"fnlwgt\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(fnlwgt,None),<function1>,Some(<function1>),None)",
#       "column_name": "fnlwgt",
#       "current_value": "DataType: Integral",
#       "description": "'fnlwgt' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"fnlwgt\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('workclass' has value range ' Private', ' Self-emp-not-inc', ' Local-gov', ' ?', ' State-gov', ' Self-emp-inc', ' Federal-gov', ' Without-pay', ' Never-worked',`workclass` IN (' Private', ' Self-emp-not-inc', ' Local-gov', ' ?', ' State-gov', ' Self-emp-inc', ' Federal-gov', ' Without-pay', ' Never-worked'),None,List(workclass),None))",
#       "column_name": "workclass",
#       "current_value": "Compliance: 1",
#       "description": "'workclass' has value range ' Private', ' Self-emp-not-inc', ' Local-gov', ' ?', ' State-gov', ' Self-emp-inc', ' Federal-gov', ' Without-pay', ' Never-worked'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"workclass\", [\" Private\", \" Self-emp-not-inc\", \" Local-gov\", \" ?\", \" State-gov\", \" Self-emp-inc\", \" Federal-gov\", \" Without-pay\", \" Never-worked\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(workclass,None,None))",
#       "column_name": "workclass",
#       "current_value": "Completeness: 1.0",
#       "description": "'workclass' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"workclass\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('workclass' has value range ' Private', ' Self-emp-not-inc', ' Local-gov', ' ?', ' State-gov' for at least 93.0% of values,`workclass` IN (' Private', ' Self-emp-not-inc', ' Local-gov', ' ?', ' State-gov'),None,List(workclass),None))",
#       "column_name": "workclass",
#       "current_value": "Compliance: 0.9353425330658041",
#       "description": "'workclass' has value range ' Private', ' Self-emp-not-inc', ' Local-gov', ' ?', ' State-gov' for at least 93.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"workclass\", [\" Private\", \" Self-emp-not-inc\", \" Local-gov\", \" ?\", \" State-gov\"], lambda x: x >= 0.93, \"It should be above 0.93!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('capital-loss' has value range '0', '1902', '1977', '1887', '2415', '1485', '1848', '1590', '1602', '1876', '1740', '1672', '1741', '1564', '2258', '1719', '1980', '1669', '1408', '2001', '2002', '1579', '2051', '1721', '1974', '2339', '1504', '2377', '1628', '2179', '2444', '1762', '2205', '625', '2559', '2057', '2824', '2042', '1573', '1651', '1092', '2392', '1340', '1617', '2174', '1380', '1594', '1668', '1726', '2246', '2129', '2231', '2603', '1258', '880', '2206', '323', '2547', '2149', '1825', '213', '3004', '3770', '2457', '1138', '1411', '653', '2472', '1816', '2238', '1510', '1944', '1429', '1735', '1648', '1844', '4356', '419', '2267', '2163', '810', '2282', '2467', '3683', '2754', '3175', '2352', '3900', '1755', '974', '2489', '1870', '1539', '2465', '1911', '2080', '1421', '155', '2201',`capital-loss` IN ('0', '1902', '1977', '1887', '2415', '1485', '1848', '1590', '1602', '1876', '1740', '1672', '1741', '1564', '2258', '1719', '1980', '1669', '1408', '2001', '2002', '1579', '2051', '1721', '1974', '2339', '1504', '2377', '1628', '2179', '2444', '1762', '2205', '625', '2559', '2057', '2824', '2042', '1573', '1651', '1092', '2392', '1340', '1617', '2174', '1380', '1594', '1668', '1726', '2246', '2129', '2231', '2603', '1258', '880', '2206', '323', '2547', '2149', '1825', '213', '3004', '3770', '2457', '1138', '1411', '653', '2472', '1816', '2238', '1510', '1944', '1429', '1735', '1648', '1844', '4356', '419', '2267', '2163', '810', '2282', '2467', '3683', '2754', '3175', '2352', '3900', '1755', '974', '2489', '1870', '1539', '2465', '1911', '2080', '1421', '155', '2201'),None,List(capital-loss),None))",
#       "column_name": "capital-loss",
#       "current_value": "Compliance: 1",
#       "description": "'capital-loss' has value range '0', '1902', '1977', '1887', '2415', '1485', '1848', '1590', '1602', '1876', '1740', '1672', '1741', '1564', '2258', '1719', '1980', '1669', '1408', '2001', '2002', '1579', '2051', '1721', '1974', '2339', '1504', '2377', '1628', '2179', '2444', '1762', '2205', '625', '2559', '2057', '2824', '2042', '1573', '1651', '1092', '2392', '1340', '1617', '2174', '1380', '1594', '1668', '1726', '2246', '2129', '2231', '2603', '1258', '880', '2206', '323', '2547', '2149', '1825', '213', '3004', '3770', '2457', '1138', '1411', '653', '2472', '1816', '2238', '1510', '1944', '1429', '1735', '1648', '1844', '4356', '419', '2267', '2163', '810', '2282', '2467', '3683', '2754', '3175', '2352', '3900', '1755', '974', '2489', '1870', '1539', '2465', '1911', '2080', '1421', '155', '2201'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"capital-loss\", [\"0\", \"1902\", \"1977\", \"1887\", \"2415\", \"1485\", \"1848\", \"1590\", \"1602\", \"1876\", \"1740\", \"1672\", \"1741\", \"1564\", \"2258\", \"1719\", \"1980\", \"1669\", \"1408\", \"2001\", \"2002\", \"1579\", \"2051\", \"1721\", \"1974\", \"2339\", \"1504\", \"2377\", \"1628\", \"2179\", \"2444\", \"1762\", \"2205\", \"625\", \"2559\", \"2057\", \"2824\", \"2042\", \"1573\", \"1651\", \"1092\", \"2392\", \"1340\", \"1617\", \"2174\", \"1380\", \"1594\", \"1668\", \"1726\", \"2246\", \"2129\", \"2231\", \"2603\", \"1258\", \"880\", \"2206\", \"323\", \"2547\", \"2149\", \"1825\", \"213\", \"3004\", \"3770\", \"2457\", \"1138\", \"1411\", \"653\", \"2472\", \"1816\", \"2238\", \"1510\", \"1944\", \"1429\", \"1735\", \"1648\", \"1844\", \"4356\", \"419\", \"2267\", \"2163\", \"810\", \"2282\", \"2467\", \"3683\", \"2754\", \"3175\", \"2352\", \"3900\", \"1755\", \"974\", \"2489\", \"1870\", \"1539\", \"2465\", \"1911\", \"2080\", \"1421\", \"155\", \"2201\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(capital-loss,None,None))",
#       "column_name": "capital-loss",
#       "current_value": "Completeness: 1.0",
#       "description": "'capital-loss' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"capital-loss\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('capital-loss' has value range '0' for at least 95.0% of values,`capital-loss` IN ('0'),None,List(capital-loss),None))",
#       "column_name": "capital-loss",
#       "current_value": "Compliance: 0.9532779165472339",
#       "description": "'capital-loss' has value range '0' for at least 95.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"capital-loss\", [\"0\"], lambda x: x >= 0.95, \"It should be above 0.95!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('capital-loss' has no negative values,capital-loss >= 0,None,List(capital-loss),None))",
#       "column_name": "capital-loss",
#       "current_value": "Minimum: 0.0",
#       "description": "'capital-loss' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"capital-loss\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(capital-loss,None),<function1>,Some(<function1>),None)",
#       "column_name": "capital-loss",
#       "current_value": "DataType: Integral",
#       "description": "'capital-loss' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"capital-loss\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('occupation' has value range ' Prof-specialty', ' Craft-repair', ' Exec-managerial', ' Adm-clerical', ' Sales', ' Other-service', ' Machine-op-inspct', ' ?', ' Transport-moving', ' Handlers-cleaners', ' Farming-fishing', ' Tech-support', ' Protective-serv', ' Priv-house-serv', ' Armed-Forces',`occupation` IN (' Prof-specialty', ' Craft-repair', ' Exec-managerial', ' Adm-clerical', ' Sales', ' Other-service', ' Machine-op-inspct', ' ?', ' Transport-moving', ' Handlers-cleaners', ' Farming-fishing', ' Tech-support', ' Protective-serv', ' Priv-house-serv', ' Armed-Forces'),None,List(occupation),None))",
#       "column_name": "occupation",
#       "current_value": "Compliance: 1",
#       "description": "'occupation' has value range ' Prof-specialty', ' Craft-repair', ' Exec-managerial', ' Adm-clerical', ' Sales', ' Other-service', ' Machine-op-inspct', ' ?', ' Transport-moving', ' Handlers-cleaners', ' Farming-fishing', ' Tech-support', ' Protective-serv', ' Priv-house-serv', ' Armed-Forces'",
#       "suggesting_rule": "CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3688/0x0000000841591840@525543c9)",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"occupation\", [\" Prof-specialty\", \" Craft-repair\", \" Exec-managerial\", \" Adm-clerical\", \" Sales\", \" Other-service\", \" Machine-op-inspct\", \" ?\", \" Transport-moving\", \" Handlers-cleaners\", \" Farming-fishing\", \" Tech-support\", \" Protective-serv\", \" Priv-house-serv\", \" Armed-Forces\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(occupation,None,None))",
#       "column_name": "occupation",
#       "current_value": "Completeness: 1.0",
#       "description": "'occupation' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"occupation\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('occupation' has value range ' Prof-specialty', ' Craft-repair', ' Exec-managerial', ' Adm-clerical', ' Sales', ' Other-service', ' Machine-op-inspct', ' ?', ' Transport-moving', ' Handlers-cleaners' for at least 91.0% of values,`occupation` IN (' Prof-specialty', ' Craft-repair', ' Exec-managerial', ' Adm-clerical', ' Sales', ' Other-service', ' Machine-op-inspct', ' ?', ' Transport-moving', ' Handlers-cleaners'),None,List(occupation),None))",
#       "column_name": "occupation",
#       "current_value": "Compliance: 0.9144998157323615",
#       "description": "'occupation' has value range ' Prof-specialty', ' Craft-repair', ' Exec-managerial', ' Adm-clerical', ' Sales', ' Other-service', ' Machine-op-inspct', ' ?', ' Transport-moving', ' Handlers-cleaners' for at least 91.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3689/0x0000000841592040@1965a79a,WaldIntervalStrategy())",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"occupation\", [\" Prof-specialty\", \" Craft-repair\", \" Exec-managerial\", \" Adm-clerical\", \" Sales\", \" Other-service\", \" Machine-op-inspct\", \" ?\", \" Transport-moving\", \" Handlers-cleaners\"], lambda x: x >= 0.91, \"It should be above 0.91!\")"
#     }
#   ]
# }

# %%
# Cell 7: Verify Data Quality
print("=== Verifying Data Quality ===")
check = (Check(spark, CheckLevel.Warning, "Adult Data Quality Check")
    .hasSize(lambda x: x >= 30000)  # Adjust threshold based on your dataset size
    .isComplete("age")
    .isComplete("income")
    .isNonNegative("hours_per_week")
    .isContainedIn("income", [">50K", "<=50K"]))

verification_result = (VerificationSuite(spark)
    .onData(adult_data)
    .addCheck(check)
    .run())
verification_result_df = VerificationResult.checkResultsAsDataFrame(spark, verification_result)
verification_result_df.show(truncate=False)
# Out:
# === Verifying Data Quality ===
# +------------------------+-----------+------------+----------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------------------------+
# |check                   |check_level|check_status|constraint                                                                                                                                                |constraint_status|constraint_message                                  |
# +------------------------+-----------+------------+----------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------------------------+
# |Adult Data Quality Check|Warning    |Warning     |SizeConstraint(Size(None))                                                                                                                                |Success          |                                                    |
# |Adult Data Quality Check|Warning    |Warning     |CompletenessConstraint(Completeness(age,None,None))                                                                                                       |Success          |                                                    |
# |Adult Data Quality Check|Warning    |Warning     |CompletenessConstraint(Completeness(income,None,None))                                                                                                    |Success          |                                                    |
# |Adult Data Quality Check|Warning    |Warning     |ComplianceConstraint(Compliance(hours_per_week is non-negative,COALESCE(CAST(hours_per_week AS DECIMAL(20,10)), 0.0) >= 0,None,List(hours_per_week),None))|Failure          |Input data does not include column hours_per_week!  |
# |Adult Data Quality Check|Warning    |Warning     |ComplianceConstraint(Compliance(income contained in >50K,<=50K,`income` IS NULL OR `income` IN ('>50K','<=50K'),None,List(income),None))                  |Failure          |Value: 0.0 does not meet the constraint requirement!|
# +------------------------+-----------+------------+----------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------------------------+

# %%
# Cell 8: Analyze Data Metrics
print("=== Analyzing Data Metrics ===")
analysis_result = (AnalysisRunner(spark)
    .onData(adult_data)
    .addAnalyzer(Size())
    .addAnalyzer(Completeness("income"))
    .addAnalyzer(Completeness("workclass"))
    .addAnalyzer(Mean("age"))
    .addAnalyzer(ApproxCountDistinct("education"))
    .addAnalyzer(CountDistinct("income"))
    .run())

# Display analysis results
metrics_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysis_result)
metrics_df.show(truncate=False)
# Out:
# === Analyzing Data Metrics ===
# +-------+---------+-------------------+-------+
# |entity |instance |name               |value  |
# +-------+---------+-------------------+-------+
# |Column |education|ApproxCountDistinct|16.0   |
# |Column |income   |CountDistinct      |4.0    |
# |Dataset|*        |Size               |48842.0|
# |Column |workclass|Completeness       |1.0    |
# |Column |income   |Completeness       |1.0    |
# +-------+---------+-------------------+-------+

# %%
# Cell 9: Custom Analysis - Distribution of Age Groups
print("=== Age Distribution Analysis ===")
adult_data.groupBy("age").count().orderBy("age").show(20)

# Cell 10: Custom Analysis - Income Distribution by Education
print("=== Income Distribution by Education ===")
adult_data.groupBy("education", "income").count().orderBy("education", "income").show(20)
# Out:
# === Age Distribution Analysis ===
# +---+-----+
# |age|count|
# +---+-----+
# | 17|  595|
# | 18|  862|
# | 19| 1053|
# | 20| 1113|
# | 21| 1096|
# | 22| 1178|
# | 23| 1329|
# | 24| 1206|
# | 25| 1195|
# | 26| 1153|
# | 27| 1232|
# | 28| 1280|
# | 29| 1223|
# | 30| 1278|
# | 31| 1325|
# | 32| 1253|
# | 33| 1335|
# | 34| 1303|
# | 35| 1337|
# | 36| 1348|
# +---+-----+
# only showing top 20 rows
#
# === Income Distribution by Education ===
# +---------+-------+-----+
# |education| income|count|
# +---------+-------+-----+
# |     10th|  <=50K|  871|
# |     10th| <=50K.|  431|
# |     10th|   >50K|   62|
# |     10th|  >50K.|   25|
# |     11th|  <=50K| 1115|
# |     11th| <=50K.|  605|
# |     11th|   >50K|   60|
# |     11th|  >50K.|   32|
# |     12th|  <=50K|  400|
# |     12th| <=50K.|  209|
# |     12th|   >50K|   33|
# |     12th|  >50K.|   15|
# |  1st-4th|  <=50K|  162|
# |  1st-4th| <=50K.|   77|
# |  1st-4th|   >50K|    6|
# |  1st-4th|  >50K.|    2|
# |  5th-6th|  <=50K|  317|
# |  5th-6th| <=50K.|  165|
# |  5th-6th|   >50K|   16|
# |  5th-6th|  >50K.|   11|
# +---------+-------+-----+
# only showing top 20 rows
